# %% [markdown]
# What the heck happened to the previous notebook?
#
# Latex:  $E = mc^2$

# %%
print "hello world!"
# Out:
# hello world!

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))

# %%
# %load test_load

# %%
# This file can be loaded.

print "I have been loaded into the notebook"
# Out:
# I have been loaded into the notebook

# %% [markdown]
# Index
# =====
#
# Now I'd like to figure out how to create a link to another notebook.
#
# This is a link to [tutorial](01_Introduction.ipynb)
#
# This is a link to a link to a folder [astropy4scipy2014](astropy/astropy4scipy2014/)
